# %%
import csv
import numpy as np # linear algebra
import pandas as pd 
import os
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)

# Normal distributed x and y vector with mean 0 and standard deviation 1
x = np.random.normal(1, 1, 500)
y = np.random.normal(-1, 1, 500)
X = np.vstack((x, y)).T

plt.scatter(X[:, 0], X[:, 1])
plt.title('Generated Data')
plt.axis('equal')
# Out:
# (-2.793722453198532, 4.52707911514822, -3.752338451731253, 1.9381781162844212)

# %%
train_data = pd.read_csv('mnist_train.csv')

# %%
df7 = train_data.loc[train_data['label']==7]
df1 = train_data.loc[train_data['label']==1]

# %%
some_digit = df1[20]
some_digit_show = plt.imshow(X[20].reshape(28,28), cmap=mpl.cm.binary)
y[20]
# Out:
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#
#    3360             try:
#
# -> 3361                 return self._engine.get_loc(casted_key)
#
#    3362             except KeyError as err:
#
#
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
#
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
#
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
#
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
#
#
# KeyError: 20
#
#
#
# The above exception was the direct cause of the following exception:
#
#
#
# KeyError                                  Traceback (most recent call last)
#
# /tmp/ipykernel_15134/2140417060.py in <module>
#
# ----> 1 some_digit = df1[20]
#
#       2 some_digit_show = plt.imshow(X[20].reshape(28,28), cmap=mpl.cm.binary)
#
#       3 y[20]
#
#
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#
#    3456             if self.columns.nlevels > 1:
#
#    3457                 return self._getitem_multilevel(key)
#
# -> 3458             indexer = self.columns.get_loc(key)
#
#    3459             if is_integer(indexer):
#
#    3460                 indexer = [indexer]
#
#
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#
#    3361                 return self._engine.get_loc(casted_key)
#
#    3362             except KeyError as err:
#
# -> 3363                 raise KeyError(key) from err
#
#    3364
#
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
#
#
# KeyError: 20
